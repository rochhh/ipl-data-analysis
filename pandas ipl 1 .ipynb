# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv('C:/Users/paliw/Desktop/Roadmap/practice datasets/matches.csv')
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.shape
# Out:
# (755, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               755 non-null    int64
#  1   season           755 non-null    int64
#  2   city             748 non-null    object
#  3   date             755 non-null    object
#  4   team1            755 non-null    object
#  5   team2            755 non-null    object
#  6   toss_winner      755 non-null    object
#  7   toss_decision    755 non-null    object
#  8   result           755 non-null    object
#  9   dl_applied       755 non-null    int64
#  10  winner           751 non-null    object
#  11  win_by_runs      755 non-null    int64
#  12  win_by_wickets   755 non-null    int64
#  13  player_of_match  751 non-null    object
#  14  venue            755 non-null    object
#  15  umpire1          753 non-null    object
#  16  umpire2          753 non-null    object
# ...

# %%
data['winner'].iloc[[69,96,696]]
# Out:
# 69        Rajasthan Royals
# 96         Kings XI Punjab
# 696    Chennai Super Kings
# Name: winner, dtype: object

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 750          Chennai Super Kings              Kings XI Punjab
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
## tell me the umpire1 and umpire2 name between team1 and team2 with date and tell the winner 


data.iloc[69:70,[2,3,4,5,10]]
# Out:
#          city        date                        team1             team2  \
# 69  Bangalore  26-04-2008  Royal Challengers Bangalore  Rajasthan Royals
#
#               winner
# 69  Rajasthan Royals

# %%
mask1=data['city']=='Bangalore'

# %%
data[mask1].shape[0]
# Out:
# 66

# %%
def get_city_matches_played(city):
    mask1=data['city']==city
    return data[mask1].shape[0]

# %%
get_city_matches_played('Pune')
# Out:
# 38

# %%
# matches played in Bangalore but before the date 


mask2=data['city']=='Bangalore'
mask3=data['date']>'05-04-2018'

# %%
data[mask2 & mask3]
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 11    12    2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 16    17    2017  Bangalore  16-04-2017       Rising Pune Supergiant
# 29    30    2017  Bangalore  27-04-2017  Royal Challengers Bangalore
# 41    42    2017  Bangalore  05-05-2017              Kings XI Punjab
# 44    45    2017  Bangalore  07-05-2017  Royal Challengers Bangalore
# 56    57    2017  Bangalore  17-05-2017          Sunrisers Hyderabad
# 57    58    2017  Bangalore  19-05-2017        Kolkata Knight Riders
# 59    60    2008  Bangalore  18-04-2008        Kolkata Knight Riders
# 69    70    2008  Bangalore  26-04-2008  Royal Challengers Bangalore
# 73    74    2008  Bangalore  28-04-2008          Chennai Super Kings
# 83    84    2008  Bangalore  05-05-2008  Royal Challengers Bangalore
# 89    90    2008  Bangalore  28-05-2008  Royal Challengers Bangalore
# ...

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#### find the man of the match between 10-04-2017 and 10-04-2018 where the matches were played in Mumbai


mask4=data['city']=='Mumbai'
mask5=data['player_of_match']==data['player_of_match']
mask6=data['date'].between('11-04-2017','10-04-2018')

# %%
data[mask4 & mask6]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 108
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().head().plot(kind='barh')  # we can even plot with .plot after head
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data['city'].value_counts().plot(kind='pie' , figsize=(30,30))
# Out:
# <AxesSubplot:ylabel='city'>

# %%
data['season'].plot(kind='hist', bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
check_index=data['winner']

# %%
recheck=data['winner'].value_counts()

# %%
recheck['Mumbai Indians'].values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [166], in <module>
# ----> 1 recheck['Mumbai Indians'].values
#
# AttributeError: 'numpy.int64' object has no attribute 'values'

# %%
(data['team1'].value_counts() +data['team2'].value_counts().sort_values()).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['team2'].value_counts().sort_values(ascending=False)
# Out:
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            74
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.sort_values('season' , ascending=False)
# Out:
#         id  season           city        date                  team1  \
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 725  11321    2019      Hyderabad  14-04-2019         Delhi Capitals
# 723  11319    2019         Mohali  13-04-2019        Kings XI Punjab
# 722  11318    2019         Mumbai  13-04-2019         Mumbai Indians
# 721  11317    2019        Kolkata  12-04-2019  Kolkata Knight Riders
# ..     ...     ...            ...         ...                    ...
# 85      86    2008         Mumbai  07-05-2008       Rajasthan Royals
# 86      87    2008          Delhi  08-05-2008       Delhi Daredevils
# 87      88    2008        Kolkata  08-05-2008  Kolkata Knight Riders
# 88      89    2008         Jaipur  09-05-2008        Deccan Chargers
# 72      73    2008     Chandigarh  27-04-2008       Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.sort_values(['city','venue'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  16-04-2014        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  18-04-2014          Chennai Super Kings
# 460  461    2014  Abu Dhabi  18-04-2014          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  21-04-2014          Chennai Super Kings
# 470  471    2014  Abu Dhabi  26-04-2014  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  23-04-2014          Chennai Super Kings
# 468  469    2014        NaN  25-04-2014          Sunrisers Hyderabad
# 469  470    2014        NaN  25-04-2014               Mumbai Indians
# 474  475    2014        NaN  28-04-2014  Royal Challengers Bangalore
# 476  477    2014        NaN  30-04-2014          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
# below code 199 -- as we made a dataframe using drop dublicates , we can then select a coloum like we did below(season , winner and then sort the values in ascending order to make it look more clean  )

# %%
data.drop_duplicates(subset='season',keep='last')[['season','winner']].sort_values('season')  #
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians
# 695    2018    Chennai Super Kings
# 754    2019    Chennai Super Kings
